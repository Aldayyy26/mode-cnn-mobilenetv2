# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense, Activation,Dropout,Conv2D, MaxPooling2D,BatchNormalization, Flatten,Input
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras import regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model, load_model, Sequential
from keras.callbacks import ModelCheckpoint
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import os
import seaborn as sns
sns.set_style('darkgrid')
from sklearn.metrics import confusion_matrix, classification_report
from IPython.display import display, HTML

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ### iterate through the folders to create a dataframe of the form filepaths labels

# %%
sdir= '/content/gdrive/MyDrive/Semester5/PengolahanCitra/capstone/dataset jalan/all'

filepaths=[]
labels=[]
classlist=os.listdir(sdir)
for klass in classlist:
    classpath=os.path.join(sdir,klass)
    if os.path.isdir(classpath):
        flist=os.listdir(classpath)
        for f in flist:
            fpath=os.path.join(classpath,f)
            filepaths.append(fpath)
            labels.append(klass)
Fseries= pd.Series(filepaths, name='filepaths')
Lseries=pd.Series(labels, name='labels')
df=pd.concat([Fseries, Lseries], axis=1)
print (df.head())
print (df['labels'].value_counts())
# Out:
#                                            filepaths       labels
# 0  /content/gdrive/MyDrive/Semester5/PengolahanCi...  rusak_parah
# 1  /content/gdrive/MyDrive/Semester5/PengolahanCi...  rusak_parah
# 2  /content/gdrive/MyDrive/Semester5/PengolahanCi...  rusak_parah
# 3  /content/gdrive/MyDrive/Semester5/PengolahanCi...  rusak_parah
# 4  /content/gdrive/MyDrive/Semester5/PengolahanCi...  rusak_parah
# rusak_parah     200
# rusak_sedang    200
# jalan_retak     200
# rusak_kecil     200
# Name: labels, dtype: int64

# %% [markdown]
# ### split df into train_df, test_df and valid_df

# %%
train_split=.8
test_split=.1
dummy_split=test_split/(1-train_split)
train_df, dummy_df=train_test_split(df, train_size=train_split, shuffle=True, random_state=123)
test_df, valid_df=train_test_split(dummy_df, train_size=dummy_split, shuffle=True, random_state=123)
print ('train_df length: ', len(train_df), '  test_df length: ', len(test_df), '  valid_df length: ', len(valid_df))
# Out:
# train_df length:  640   test_df length:  80   valid_df length:  80

# %% [markdown]
# ### create train, test, valid  generators

# %%
height=128
width=128
channels=3
batch_size=32

img_shape=(height, width, channels)
img_size=(height, width)
length=len(test_df)
test_batch_size=sorted([int(length/n) for n in range(1,length+1) if length % n ==0 and length/n<=80],reverse=True)[0]
test_steps=int(length/test_batch_size)
print ( 'test batch size: ' ,test_batch_size, '  test steps: ', test_steps)

gen=ImageDataGenerator(
    rescale=1./255,
    )
train_gen=gen.flow_from_dataframe( train_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=True, batch_size=batch_size)

validgen=ImageDataGenerator(rescale=1./255)
valid_gen=validgen.flow_from_dataframe( valid_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=True, batch_size=batch_size)

testgen=ImageDataGenerator(rescale=1./255)
test_gen=testgen.flow_from_dataframe( test_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=False, batch_size=test_batch_size)

classes=list(train_gen.class_indices.keys())
print (classes)
class_count=len(classes)
# Out:
# test batch size:  80   test steps:  1
# Found 639 validated image filenames belonging to 4 classes.
# Found 80 validated image filenames belonging to 4 classes.
# Found 80 validated image filenames belonging to 4 classes.
# ['jalan_retak', 'rusak_kecil', 'rusak_parah', 'rusak_sedang']
# /usr/local/lib/python3.10/dist-packages/keras/src/preprocessing/image.py:1137: UserWarning: Found 1 invalid image filename(s) in x_col="filepaths". These filename(s) will be ignored.
#   warnings.warn(

# %% [markdown]
# ### create function to show some image examples

# %%
def show_image_samples(gen):
    test_dict=test_gen.class_indices
    classes=list(test_dict.keys())
    images,labels=next(gen) # get a sample batch from the generator
    plt.figure(figsize=(20, 20))
    length=len(labels)
    if length<25:   #show maximum of 25 images
        r=length
    else:
        r=25
    for i in range(r):
        plt.subplot(5, 5, i + 1)
        image=images[i]
        plt.imshow(image)
        index=np.argmax(labels[i])
        class_name=classes[index]
        plt.title(class_name, color='blue', fontsize=16)
        plt.axis('off')
    plt.show()

# %%
show_image_samples(train_gen)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### create the model

# %%
base_model=tf.keras.applications.MobileNetV2(include_top=False, weights="imagenet",input_tensor=Input(shape=(128,128,3)))
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
base_model.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  Conv1 (Conv2D)              (None, 64, 64, 32)           864       ['input_1[0][0]']
#
#  bn_Conv1 (BatchNormalizati  (None, 64, 64, 32)           128       ['Conv1[0][0]']
#  on)
#
#  Conv1_relu (ReLU)           (None, 64, 64, 32)           0         ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (D  (None, 64, 64, 32)           288       ['Conv1_relu[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv_depthwise_BN  (None, 64, 64, 32)           128       ['expanded_conv_depthwise[0][0
#   (BatchNormalization)                                              ]']
#
#  expanded_conv_depthwise_re  (None, 64, 64, 32)           0         ['expanded_conv_depthwise_BN[0
#  lu (ReLU)                                                          ][0]']
#
#  expanded_conv_project (Con  (None, 64, 64, 16)           512       ['expanded_conv_depthwise_relu
#  v2D)                                                               [0][0]']
#
#  expanded_conv_project_BN (  (None, 64, 64, 16)           64        ['expanded_conv_project[0][0]'
#  BatchNormalization)                                                ]
#
#  block_1_expand (Conv2D)     (None, 64, 64, 96)           1536      ['expanded_conv_project_BN[0][
#                                                                     0]']
#
#  block_1_expand_BN (BatchNo  (None, 64, 64, 96)           384       ['block_1_expand[0][0]']
#  rmalization)
#
#  block_1_expand_relu (ReLU)  (None, 64, 64, 96)           0         ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D  (None, 65, 65, 96)           0         ['block_1_expand_relu[0][0]']
#  )
#
#  block_1_depthwise (Depthwi  (None, 32, 32, 96)           864       ['block_1_pad[0][0]']
#  seConv2D)
#
#  block_1_depthwise_BN (Batc  (None, 32, 32, 96)           384       ['block_1_depthwise[0][0]']
#  hNormalization)
#
#  block_1_depthwise_relu (Re  (None, 32, 32, 96)           0         ['block_1_depthwise_BN[0][0]']
#  LU)
#
#  block_1_project (Conv2D)    (None, 32, 32, 24)           2304      ['block_1_depthwise_relu[0][0]
#                                                                     ']
#
#  block_1_project_BN (BatchN  (None, 32, 32, 24)           96        ['block_1_project[0][0]']
#  ormalization)
#
#  block_2_expand (Conv2D)     (None, 32, 32, 144)          3456      ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNo  (None, 32, 32, 144)          576       ['block_2_expand[0][0]']
#  rmalization)
#
#  block_2_expand_relu (ReLU)  (None, 32, 32, 144)          0         ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (Depthwi  (None, 32, 32, 144)          1296      ['block_2_expand_relu[0][0]']
#  seConv2D)
#
#  block_2_depthwise_BN (Batc  (None, 32, 32, 144)          576       ['block_2_depthwise[0][0]']
#  hNormalization)
#
#  block_2_depthwise_relu (Re  (None, 32, 32, 144)          0         ['block_2_depthwise_BN[0][0]']
#  LU)
#
#  block_2_project (Conv2D)    (None, 32, 32, 24)           3456      ['block_2_depthwise_relu[0][0]
#                                                                     ']
#
#  block_2_project_BN (BatchN  (None, 32, 32, 24)           96        ['block_2_project[0][0]']
#  ormalization)
#
#  block_2_add (Add)           (None, 32, 32, 24)           0         ['block_1_project_BN[0][0]',
#                                                                      'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)     (None, 32, 32, 144)          3456      ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNo  (None, 32, 32, 144)          576       ['block_3_expand[0][0]']
#  rmalization)
#
#  block_3_expand_relu (ReLU)  (None, 32, 32, 144)          0         ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D  (None, 33, 33, 144)          0         ['block_3_expand_relu[0][0]']
#  )
#
#  block_3_depthwise (Depthwi  (None, 16, 16, 144)          1296      ['block_3_pad[0][0]']
#  seConv2D)
#
#  block_3_depthwise_BN (Batc  (None, 16, 16, 144)          576       ['block_3_depthwise[0][0]']
#  hNormalization)
#
#  block_3_depthwise_relu (Re  (None, 16, 16, 144)          0         ['block_3_depthwise_BN[0][0]']
#  LU)
#
#  block_3_project (Conv2D)    (None, 16, 16, 32)           4608      ['block_3_depthwise_relu[0][0]
#                                                                     ']
#
#  block_3_project_BN (BatchN  (None, 16, 16, 32)           128       ['block_3_project[0][0]']
#  ormalization)
#
#  block_4_expand (Conv2D)     (None, 16, 16, 192)          6144      ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNo  (None, 16, 16, 192)          768       ['block_4_expand[0][0]']
#  rmalization)
#
#  block_4_expand_relu (ReLU)  (None, 16, 16, 192)          0         ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (Depthwi  (None, 16, 16, 192)          1728      ['block_4_expand_relu[0][0]']
#  seConv2D)
#
#  block_4_depthwise_BN (Batc  (None, 16, 16, 192)          768       ['block_4_depthwise[0][0]']
#  hNormalization)
#
#  block_4_depthwise_relu (Re  (None, 16, 16, 192)          0         ['block_4_depthwise_BN[0][0]']
#  LU)
#
#  block_4_project (Conv2D)    (None, 16, 16, 32)           6144      ['block_4_depthwise_relu[0][0]
#                                                                     ']
#
#  block_4_project_BN (BatchN  (None, 16, 16, 32)           128       ['block_4_project[0][0]']
#  ormalization)
#
#  block_4_add (Add)           (None, 16, 16, 32)           0         ['block_3_project_BN[0][0]',
#                                                                      'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)     (None, 16, 16, 192)          6144      ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNo  (None, 16, 16, 192)          768       ['block_5_expand[0][0]']
#  rmalization)
#
#  block_5_expand_relu (ReLU)  (None, 16, 16, 192)          0         ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (Depthwi  (None, 16, 16, 192)          1728      ['block_5_expand_relu[0][0]']
#  seConv2D)
#
#  block_5_depthwise_BN (Batc  (None, 16, 16, 192)          768       ['block_5_depthwise[0][0]']
#  hNormalization)
#
#  block_5_depthwise_relu (Re  (None, 16, 16, 192)          0         ['block_5_depthwise_BN[0][0]']
#  LU)
#
#  block_5_project (Conv2D)    (None, 16, 16, 32)           6144      ['block_5_depthwise_relu[0][0]
#                                                                     ']
#
#  block_5_project_BN (BatchN  (None, 16, 16, 32)           128       ['block_5_project[0][0]']
#  ormalization)
#
#  block_5_add (Add)           (None, 16, 16, 32)           0         ['block_4_add[0][0]',
#                                                                      'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)     (None, 16, 16, 192)          6144      ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNo  (None, 16, 16, 192)          768       ['block_6_expand[0][0]']
#  rmalization)
#
#  block_6_expand_relu (ReLU)  (None, 16, 16, 192)          0         ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D  (None, 17, 17, 192)          0         ['block_6_expand_relu[0][0]']
#  )
#
#  block_6_depthwise (Depthwi  (None, 8, 8, 192)            1728      ['block_6_pad[0][0]']
#  seConv2D)
#
#  block_6_depthwise_BN (Batc  (None, 8, 8, 192)            768       ['block_6_depthwise[0][0]']
#  hNormalization)
#
#  block_6_depthwise_relu (Re  (None, 8, 8, 192)            0         ['block_6_depthwise_BN[0][0]']
#  LU)
#
#  block_6_project (Conv2D)    (None, 8, 8, 64)             12288     ['block_6_depthwise_relu[0][0]
#                                                                     ']
#
#  block_6_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_6_project[0][0]']
#  ormalization)
#
#  block_7_expand (Conv2D)     (None, 8, 8, 384)            24576     ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNo  (None, 8, 8, 384)            1536      ['block_7_expand[0][0]']
#  rmalization)
#
#  block_7_expand_relu (ReLU)  (None, 8, 8, 384)            0         ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (Depthwi  (None, 8, 8, 384)            3456      ['block_7_expand_relu[0][0]']
#  seConv2D)
#
#  block_7_depthwise_BN (Batc  (None, 8, 8, 384)            1536      ['block_7_depthwise[0][0]']
#  hNormalization)
#
#  block_7_depthwise_relu (Re  (None, 8, 8, 384)            0         ['block_7_depthwise_BN[0][0]']
#  LU)
#
#  block_7_project (Conv2D)    (None, 8, 8, 64)             24576     ['block_7_depthwise_relu[0][0]
#                                                                     ']
#
#  block_7_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_7_project[0][0]']
#  ormalization)
#
#  block_7_add (Add)           (None, 8, 8, 64)             0         ['block_6_project_BN[0][0]',
#                                                                      'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)     (None, 8, 8, 384)            24576     ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNo  (None, 8, 8, 384)            1536      ['block_8_expand[0][0]']
#  rmalization)
#
#  block_8_expand_relu (ReLU)  (None, 8, 8, 384)            0         ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (Depthwi  (None, 8, 8, 384)            3456      ['block_8_expand_relu[0][0]']
#  seConv2D)
#
#  block_8_depthwise_BN (Batc  (None, 8, 8, 384)            1536      ['block_8_depthwise[0][0]']
#  hNormalization)
#
#  block_8_depthwise_relu (Re  (None, 8, 8, 384)            0         ['block_8_depthwise_BN[0][0]']
#  LU)
#
#  block_8_project (Conv2D)    (None, 8, 8, 64)             24576     ['block_8_depthwise_relu[0][0]
#                                                                     ']
#
#  block_8_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_8_project[0][0]']
#  ormalization)
#
#  block_8_add (Add)           (None, 8, 8, 64)             0         ['block_7_add[0][0]',
#                                                                      'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)     (None, 8, 8, 384)            24576     ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNo  (None, 8, 8, 384)            1536      ['block_9_expand[0][0]']
#  rmalization)
#
#  block_9_expand_relu (ReLU)  (None, 8, 8, 384)            0         ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (Depthwi  (None, 8, 8, 384)            3456      ['block_9_expand_relu[0][0]']
#  seConv2D)
#
#  block_9_depthwise_BN (Batc  (None, 8, 8, 384)            1536      ['block_9_depthwise[0][0]']
#  hNormalization)
#
#  block_9_depthwise_relu (Re  (None, 8, 8, 384)            0         ['block_9_depthwise_BN[0][0]']
#  LU)
#
#  block_9_project (Conv2D)    (None, 8, 8, 64)             24576     ['block_9_depthwise_relu[0][0]
#                                                                     ']
#
#  block_9_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_9_project[0][0]']
#  ormalization)
#
#  block_9_add (Add)           (None, 8, 8, 64)             0         ['block_8_add[0][0]',
#                                                                      'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)    (None, 8, 8, 384)            24576     ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchN  (None, 8, 8, 384)            1536      ['block_10_expand[0][0]']
#  ormalization)
#
#  block_10_expand_relu (ReLU  (None, 8, 8, 384)            0         ['block_10_expand_BN[0][0]']
#  )
#
#  block_10_depthwise (Depthw  (None, 8, 8, 384)            3456      ['block_10_expand_relu[0][0]']
#  iseConv2D)
#
#  block_10_depthwise_BN (Bat  (None, 8, 8, 384)            1536      ['block_10_depthwise[0][0]']
#  chNormalization)
#
#  block_10_depthwise_relu (R  (None, 8, 8, 384)            0         ['block_10_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_10_project (Conv2D)   (None, 8, 8, 96)             36864     ['block_10_depthwise_relu[0][0
#                                                                     ]']
#
#  block_10_project_BN (Batch  (None, 8, 8, 96)             384       ['block_10_project[0][0]']
#  Normalization)
#
#  block_11_expand (Conv2D)    (None, 8, 8, 576)            55296     ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchN  (None, 8, 8, 576)            2304      ['block_11_expand[0][0]']
#  ormalization)
#
#  block_11_expand_relu (ReLU  (None, 8, 8, 576)            0         ['block_11_expand_BN[0][0]']
#  )
#
#  block_11_depthwise (Depthw  (None, 8, 8, 576)            5184      ['block_11_expand_relu[0][0]']
#  iseConv2D)
#
#  block_11_depthwise_BN (Bat  (None, 8, 8, 576)            2304      ['block_11_depthwise[0][0]']
#  chNormalization)
#
#  block_11_depthwise_relu (R  (None, 8, 8, 576)            0         ['block_11_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_11_project (Conv2D)   (None, 8, 8, 96)             55296     ['block_11_depthwise_relu[0][0
#                                                                     ]']
#
#  block_11_project_BN (Batch  (None, 8, 8, 96)             384       ['block_11_project[0][0]']
#  Normalization)
#
#  block_11_add (Add)          (None, 8, 8, 96)             0         ['block_10_project_BN[0][0]',
#                                                                      'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)    (None, 8, 8, 576)            55296     ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchN  (None, 8, 8, 576)            2304      ['block_12_expand[0][0]']
#  ormalization)
#
#  block_12_expand_relu (ReLU  (None, 8, 8, 576)            0         ['block_12_expand_BN[0][0]']
#  )
#
#  block_12_depthwise (Depthw  (None, 8, 8, 576)            5184      ['block_12_expand_relu[0][0]']
#  iseConv2D)
#
#  block_12_depthwise_BN (Bat  (None, 8, 8, 576)            2304      ['block_12_depthwise[0][0]']
#  chNormalization)
#
#  block_12_depthwise_relu (R  (None, 8, 8, 576)            0         ['block_12_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_12_project (Conv2D)   (None, 8, 8, 96)             55296     ['block_12_depthwise_relu[0][0
#                                                                     ]']
#
#  block_12_project_BN (Batch  (None, 8, 8, 96)             384       ['block_12_project[0][0]']
#  Normalization)
#
#  block_12_add (Add)          (None, 8, 8, 96)             0         ['block_11_add[0][0]',
#                                                                      'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)    (None, 8, 8, 576)            55296     ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchN  (None, 8, 8, 576)            2304      ['block_13_expand[0][0]']
#  ormalization)
#
#  block_13_expand_relu (ReLU  (None, 8, 8, 576)            0         ['block_13_expand_BN[0][0]']
#  )
#
#  block_13_pad (ZeroPadding2  (None, 9, 9, 576)            0         ['block_13_expand_relu[0][0]']
#  D)
#
#  block_13_depthwise (Depthw  (None, 4, 4, 576)            5184      ['block_13_pad[0][0]']
#  iseConv2D)
#
#  block_13_depthwise_BN (Bat  (None, 4, 4, 576)            2304      ['block_13_depthwise[0][0]']
#  chNormalization)
#
#  block_13_depthwise_relu (R  (None, 4, 4, 576)            0         ['block_13_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_13_project (Conv2D)   (None, 4, 4, 160)            92160     ['block_13_depthwise_relu[0][0
#                                                                     ]']
#
#  block_13_project_BN (Batch  (None, 4, 4, 160)            640       ['block_13_project[0][0]']
#  Normalization)
#
#  block_14_expand (Conv2D)    (None, 4, 4, 960)            153600    ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchN  (None, 4, 4, 960)            3840      ['block_14_expand[0][0]']
#  ormalization)
#
#  block_14_expand_relu (ReLU  (None, 4, 4, 960)            0         ['block_14_expand_BN[0][0]']
#  )
#
#  block_14_depthwise (Depthw  (None, 4, 4, 960)            8640      ['block_14_expand_relu[0][0]']
#  iseConv2D)
#
#  block_14_depthwise_BN (Bat  (None, 4, 4, 960)            3840      ['block_14_depthwise[0][0]']
#  chNormalization)
#
#  block_14_depthwise_relu (R  (None, 4, 4, 960)            0         ['block_14_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_14_project (Conv2D)   (None, 4, 4, 160)            153600    ['block_14_depthwise_relu[0][0
#                                                                     ]']
#
#  block_14_project_BN (Batch  (None, 4, 4, 160)            640       ['block_14_project[0][0]']
#  Normalization)
#
#  block_14_add (Add)          (None, 4, 4, 160)            0         ['block_13_project_BN[0][0]',
#                                                                      'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)    (None, 4, 4, 960)            153600    ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchN  (None, 4, 4, 960)            3840      ['block_15_expand[0][0]']
#  ormalization)
#
#  block_15_expand_relu (ReLU  (None, 4, 4, 960)            0         ['block_15_expand_BN[0][0]']
#  )
#
#  block_15_depthwise (Depthw  (None, 4, 4, 960)            8640      ['block_15_expand_relu[0][0]']
#  iseConv2D)
#
#  block_15_depthwise_BN (Bat  (None, 4, 4, 960)            3840      ['block_15_depthwise[0][0]']
#  chNormalization)
#
#  block_15_depthwise_relu (R  (None, 4, 4, 960)            0         ['block_15_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_15_project (Conv2D)   (None, 4, 4, 160)            153600    ['block_15_depthwise_relu[0][0
#                                                                     ]']
#
#  block_15_project_BN (Batch  (None, 4, 4, 160)            640       ['block_15_project[0][0]']
#  Normalization)
#
#  block_15_add (Add)          (None, 4, 4, 160)            0         ['block_14_add[0][0]',
#                                                                      'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)    (None, 4, 4, 960)            153600    ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchN  (None, 4, 4, 960)            3840      ['block_16_expand[0][0]']
#  ormalization)
#
#  block_16_expand_relu (ReLU  (None, 4, 4, 960)            0         ['block_16_expand_BN[0][0]']
#  )
#
#  block_16_depthwise (Depthw  (None, 4, 4, 960)            8640      ['block_16_expand_relu[0][0]']
#  iseConv2D)
#
#  block_16_depthwise_BN (Bat  (None, 4, 4, 960)            3840      ['block_16_depthwise[0][0]']
#  chNormalization)
#
#  block_16_depthwise_relu (R  (None, 4, 4, 960)            0         ['block_16_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_16_project (Conv2D)   (None, 4, 4, 320)            307200    ['block_16_depthwise_relu[0][0
#                                                                     ]']
#
#  block_16_project_BN (Batch  (None, 4, 4, 320)            1280      ['block_16_project[0][0]']
#  Normalization)
#
#  Conv_1 (Conv2D)             (None, 4, 4, 1280)           409600    ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalizat  (None, 4, 4, 1280)           5120      ['Conv_1[0][0]']
#  ion)
#
#  out_relu (ReLU)             (None, 4, 4, 1280)           0         ['Conv_1_bn[0][0]']
#
# ==================================================================================================
# Total params: 2257984 (8.61 MB)
# Trainable params: 2223872 (8.48 MB)
# Non-trainable params: 34112 (133.25 KB)
# __________________________________________________________________________________________________

# %%
base_model.trainable = False

# %%
model_name='jalan'
print("Building model with", base_model)
model = tf.keras.Sequential([
            # Note the input shape is the desired size of the image 128x128 with 3 bytes color
            # This is the first convolution
            base_model,
            tf.keras.layers.Conv2D(filters=32, padding='same', kernel_size=3, activation='relu', strides=1),
            tf.keras.layers.MaxPool2D(pool_size=2, strides=2),
            tf.keras.layers.Dropout(rate=0.5),

            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(4, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=.0001), loss='categorical_crossentropy', metrics='accuracy')
# Out:
# Building model with <keras.src.engine.functional.Functional object at 0x791f456ee440>

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Func  (None, 4, 4, 1280)        2257984
#  tional)
#
#  conv2d (Conv2D)             (None, 4, 4, 32)          368672
#
#  max_pooling2d (MaxPooling2  (None, 2, 2, 32)          0
#  D)
#
#  dropout (Dropout)           (None, 2, 2, 32)          0
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 4)                 516
#
# =================================================================
# Total params: 2627172 (10.02 MB)
# Trainable params: 369188 (1.41 MB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________________

# %%
epochs = 100

history=model.fit(x=train_gen, epochs=epochs, validation_data=valid_gen)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 15s 474ms/step - loss: 1.9420 - accuracy: 0.3599 - val_loss: 1.1961 - val_accuracy: 0.5125
# Epoch 2/100
# 20/20 [==============================] - 6s 303ms/step - loss: 1.0998 - accuracy: 0.4883 - val_loss: 1.1090 - val_accuracy: 0.4625
# Epoch 3/100
# 20/20 [==============================] - 7s 378ms/step - loss: 0.9599 - accuracy: 0.5618 - val_loss: 1.0476 - val_accuracy: 0.5750
# Epoch 4/100
# 20/20 [==============================] - 6s 306ms/step - loss: 0.9093 - accuracy: 0.5869 - val_loss: 1.0303 - val_accuracy: 0.5625
# Epoch 5/100
# 20/20 [==============================] - 6s 309ms/step - loss: 0.8171 - accuracy: 0.6401 - val_loss: 0.9728 - val_accuracy: 0.5625
# Epoch 6/100
# 20/20 [==============================] - 7s 370ms/step - loss: 0.7792 - accuracy: 0.6354 - val_loss: 0.9363 - val_accuracy: 0.6500
# Epoch 7/100
# 20/20 [==============================] - 7s 330ms/step - loss: 0.7230 - accuracy: 0.6526 - val_loss: 0.8550 - val_accuracy: 0.6250
# Epoch 8/100
# 20/20 [==============================] - 7s 355ms/step - loss: 0.6705 - accuracy: 0.6917 - val_loss: 1.0018 - val_accuracy: 0.5375
# Epoch 9/100
# 20/20 [==============================] - 7s 324ms/step - loss: 0.6409 - accuracy: 0.7246 - val_loss: 0.9548 - val_accuracy: 0.5375
# Epoch 10/100
# 20/20 [==============================] - 7s 337ms/step - loss: 0.6035 - accuracy: 0.7214 - val_loss: 0.8448 - val_accuracy: 0.6000
# Epoch 11/100
# 20/20 [==============================] - 6s 295ms/step - loss: 0.6220 - accuracy: 0.7152 - val_loss: 0.9549 - val_accuracy: 0.5250
# Epoch 12/100
# 20/20 [==============================] - 8s 380ms/step - loss: 0.5834 - accuracy: 0.7465 - val_loss: 0.9208 - val_accuracy: 0.6000
# Epoch 13/100
# 20/20 [==============================] - 6s 306ms/step - loss: 0.5991 - accuracy: 0.7230 - val_loss: 0.8456 - val_accuracy: 0.6500
# Epoch 14/100
# 20/20 [==============================] - 7s 364ms/step - loss: 0.5569 - accuracy: 0.7574 - val_loss: 1.0050 - val_accuracy: 0.5375
# Epoch 15/100
# 20/20 [==============================] - 6s 326ms/step - loss: 0.5537 - accuracy: 0.7590 - val_loss: 0.8923 - val_accuracy: 0.6000
# Epoch 16/100
# 20/20 [==============================] - 7s 374ms/step - loss: 0.5646 - accuracy: 0.7324 - val_loss: 0.9600 - val_accuracy: 0.5625
# Epoch 17/100
# 20/20 [==============================] - 7s 335ms/step - loss: 0.5174 - accuracy: 0.7590 - val_loss: 0.9907 - val_accuracy: 0.5625
# Epoch 18/100
# 20/20 [==============================] - 7s 376ms/step - loss: 0.4719 - accuracy: 0.7903 - val_loss: 0.9250 - val_accuracy: 0.6250
# Epoch 19/100
# 20/20 [==============================] - 6s 296ms/step - loss: 0.4734 - accuracy: 0.7950 - val_loss: 0.9723 - val_accuracy: 0.5750
# Epoch 20/100
# 20/20 [==============================] - 7s 372ms/step - loss: 0.4718 - accuracy: 0.7778 - val_loss: 0.9933 - val_accuracy: 0.6000
# Epoch 21/100
# 20/20 [==============================] - 7s 349ms/step - loss: 0.4360 - accuracy: 0.8075 - val_loss: 1.3047 - val_accuracy: 0.5375
# Epoch 22/100
# 20/20 [==============================] - 7s 340ms/step - loss: 0.4428 - accuracy: 0.7997 - val_loss: 1.1250 - val_accuracy: 0.5125
# Epoch 23/100
# 20/20 [==============================] - 6s 304ms/step - loss: 0.4308 - accuracy: 0.7919 - val_loss: 1.0065 - val_accuracy: 0.5750
# Epoch 24/100
# 20/20 [==============================] - 7s 368ms/step - loss: 0.4715 - accuracy: 0.7715 - val_loss: 1.0984 - val_accuracy: 0.5375
# Epoch 25/100
# 20/20 [==============================] - 7s 334ms/step - loss: 0.4292 - accuracy: 0.8106 - val_loss: 1.1424 - val_accuracy: 0.5250
# Epoch 26/100
# 20/20 [==============================] - 6s 303ms/step - loss: 0.4300 - accuracy: 0.7840 - val_loss: 1.0621 - val_accuracy: 0.5375
# Epoch 27/100
# 20/20 [==============================] - 7s 329ms/step - loss: 0.4027 - accuracy: 0.7981 - val_loss: 1.1243 - val_accuracy: 0.5875
# Epoch 28/100
# 20/20 [==============================] - 7s 334ms/step - loss: 0.4074 - accuracy: 0.8169 - val_loss: 1.2549 - val_accuracy: 0.5625
# Epoch 29/100
# 20/20 [==============================] - 6s 305ms/step - loss: 0.4127 - accuracy: 0.7997 - val_loss: 1.1801 - val_accuracy: 0.5250
# Epoch 30/100
# 20/20 [==============================] - 7s 369ms/step - loss: 0.4212 - accuracy: 0.8106 - val_loss: 1.5462 - val_accuracy: 0.4750
# Epoch 31/100
# 20/20 [==============================] - 7s 359ms/step - loss: 0.4127 - accuracy: 0.8122 - val_loss: 1.1341 - val_accuracy: 0.5375
# Epoch 32/100
# 20/20 [==============================] - 7s 367ms/step - loss: 0.4255 - accuracy: 0.8169 - val_loss: 1.1130 - val_accuracy: 0.5625
# Epoch 33/100
# 20/20 [==============================] - 7s 343ms/step - loss: 0.4136 - accuracy: 0.8091 - val_loss: 1.2459 - val_accuracy: 0.5125
# Epoch 34/100
# 20/20 [==============================] - 6s 304ms/step - loss: 0.4159 - accuracy: 0.8169 - val_loss: 1.2537 - val_accuracy: 0.5250
# Epoch 35/100
# 20/20 [==============================] - 7s 325ms/step - loss: 0.4107 - accuracy: 0.8122 - val_loss: 1.2419 - val_accuracy: 0.5125
# Epoch 36/100
# 20/20 [==============================] - 7s 347ms/step - loss: 0.4284 - accuracy: 0.7903 - val_loss: 1.3446 - val_accuracy: 0.4875
# Epoch 37/100
# 20/20 [==============================] - 7s 339ms/step - loss: 0.4061 - accuracy: 0.8106 - val_loss: 1.1489 - val_accuracy: 0.5750
# Epoch 38/100
# 20/20 [==============================] - 6s 312ms/step - loss: 0.3846 - accuracy: 0.8216 - val_loss: 1.4191 - val_accuracy: 0.5375
# Epoch 39/100
# 20/20 [==============================] - 7s 375ms/step - loss: 0.3539 - accuracy: 0.8294 - val_loss: 1.4032 - val_accuracy: 0.5625
# Epoch 40/100
# 20/20 [==============================] - 6s 295ms/step - loss: 0.4044 - accuracy: 0.8106 - val_loss: 1.2803 - val_accuracy: 0.5125
# Epoch 41/100
# 20/20 [==============================] - 7s 377ms/step - loss: 0.3806 - accuracy: 0.8106 - val_loss: 1.1135 - val_accuracy: 0.5375
# Epoch 42/100
# 20/20 [==============================] - 6s 306ms/step - loss: 0.3854 - accuracy: 0.8169 - val_loss: 1.5009 - val_accuracy: 0.5125
# Epoch 43/100
# 20/20 [==============================] - 7s 349ms/step - loss: 0.3718 - accuracy: 0.8185 - val_loss: 1.2687 - val_accuracy: 0.5375
# Epoch 44/100
# 20/20 [==============================] - 6s 319ms/step - loss: 0.3576 - accuracy: 0.8404 - val_loss: 1.3375 - val_accuracy: 0.5875
# Epoch 45/100
# 20/20 [==============================] - 7s 372ms/step - loss: 0.3388 - accuracy: 0.8357 - val_loss: 1.3321 - val_accuracy: 0.5875
# Epoch 46/100
# 20/20 [==============================] - 7s 333ms/step - loss: 0.3622 - accuracy: 0.8263 - val_loss: 1.3856 - val_accuracy: 0.5125
# Epoch 47/100
# 20/20 [==============================] - 7s 344ms/step - loss: 0.3724 - accuracy: 0.8138 - val_loss: 1.6988 - val_accuracy: 0.5875
# Epoch 48/100
# 20/20 [==============================] - 6s 303ms/step - loss: 0.3672 - accuracy: 0.8326 - val_loss: 1.4423 - val_accuracy: 0.5750
# Epoch 49/100
# 20/20 [==============================] - 8s 399ms/step - loss: 0.3314 - accuracy: 0.8294 - val_loss: 1.6866 - val_accuracy: 0.5875
# Epoch 50/100
# 20/20 [==============================] - 6s 299ms/step - loss: 0.3728 - accuracy: 0.8404 - val_loss: 1.4361 - val_accuracy: 0.5625
# Epoch 51/100
# 20/20 [==============================] - 6s 305ms/step - loss: 0.3348 - accuracy: 0.8279 - val_loss: 1.3393 - val_accuracy: 0.5750
# Epoch 52/100
# 20/20 [==============================] - 7s 367ms/step - loss: 0.3117 - accuracy: 0.8372 - val_loss: 1.6586 - val_accuracy: 0.5500
# Epoch 53/100
# 20/20 [==============================] - 7s 326ms/step - loss: 0.3228 - accuracy: 0.8341 - val_loss: 1.6157 - val_accuracy: 0.5125
# Epoch 54/100
# 20/20 [==============================] - 7s 352ms/step - loss: 0.3099 - accuracy: 0.8372 - val_loss: 1.6070 - val_accuracy: 0.5875
# Epoch 55/100
# 20/20 [==============================] - 7s 346ms/step - loss: 0.3410 - accuracy: 0.8200 - val_loss: 1.6855 - val_accuracy: 0.5125
# Epoch 56/100
# 20/20 [==============================] - 6s 304ms/step - loss: 0.3484 - accuracy: 0.8232 - val_loss: 1.8917 - val_accuracy: 0.5750
# Epoch 57/100
# 20/20 [==============================] - 7s 373ms/step - loss: 0.3236 - accuracy: 0.8482 - val_loss: 1.5490 - val_accuracy: 0.4875
# Epoch 58/100
# 20/20 [==============================] - 6s 312ms/step - loss: 0.3564 - accuracy: 0.8294 - val_loss: 1.3016 - val_accuracy: 0.5875
# Epoch 59/100
# 20/20 [==============================] - 7s 349ms/step - loss: 0.3296 - accuracy: 0.8294 - val_loss: 1.4063 - val_accuracy: 0.5875
# Epoch 60/100
# 20/20 [==============================] - 7s 350ms/step - loss: 0.3274 - accuracy: 0.8326 - val_loss: 1.6205 - val_accuracy: 0.6125
# Epoch 61/100
# 20/20 [==============================] - 6s 309ms/step - loss: 0.3399 - accuracy: 0.8216 - val_loss: 1.3956 - val_accuracy: 0.5750
# Epoch 62/100
# 20/20 [==============================] - 6s 311ms/step - loss: 0.3253 - accuracy: 0.8451 - val_loss: 1.5715 - val_accuracy: 0.5625
# Epoch 63/100
# 20/20 [==============================] - 7s 335ms/step - loss: 0.3035 - accuracy: 0.8466 - val_loss: 1.4710 - val_accuracy: 0.5750
# Epoch 64/100
# 20/20 [==============================] - 6s 309ms/step - loss: 0.3403 - accuracy: 0.8216 - val_loss: 1.6016 - val_accuracy: 0.5625
# Epoch 65/100
# 20/20 [==============================] - 7s 379ms/step - loss: 0.3246 - accuracy: 0.8388 - val_loss: 1.3770 - val_accuracy: 0.5875
# Epoch 66/100
# 20/20 [==============================] - 6s 317ms/step - loss: 0.3047 - accuracy: 0.8482 - val_loss: 1.5698 - val_accuracy: 0.5500
# Epoch 67/100
# 20/20 [==============================] - 7s 378ms/step - loss: 0.3201 - accuracy: 0.8419 - val_loss: 1.6436 - val_accuracy: 0.5750
# Epoch 68/100
# 20/20 [==============================] - 6s 300ms/step - loss: 0.3914 - accuracy: 0.8294 - val_loss: 1.5689 - val_accuracy: 0.5250
# Epoch 69/100
# 20/20 [==============================] - 7s 375ms/step - loss: 0.3175 - accuracy: 0.8372 - val_loss: 1.7060 - val_accuracy: 0.6125
# Epoch 70/100
# 20/20 [==============================] - 6s 309ms/step - loss: 0.3190 - accuracy: 0.8576 - val_loss: 1.7695 - val_accuracy: 0.6125
# Epoch 71/100
# 20/20 [==============================] - 7s 349ms/step - loss: 0.2969 - accuracy: 0.8294 - val_loss: 1.7893 - val_accuracy: 0.5375
# Epoch 72/100
# 20/20 [==============================] - 6s 308ms/step - loss: 0.2908 - accuracy: 0.8576 - val_loss: 1.9939 - val_accuracy: 0.5750
# Epoch 73/100
# 20/20 [==============================] - 7s 374ms/step - loss: 0.3222 - accuracy: 0.8404 - val_loss: 1.5931 - val_accuracy: 0.6125
# Epoch 74/100
# 20/20 [==============================] - 6s 305ms/step - loss: 0.2978 - accuracy: 0.8513 - val_loss: 1.6657 - val_accuracy: 0.6125
# Epoch 75/100
# 20/20 [==============================] - 7s 369ms/step - loss: 0.3090 - accuracy: 0.8122 - val_loss: 1.5354 - val_accuracy: 0.5750
# Epoch 76/100
# 20/20 [==============================] - 6s 309ms/step - loss: 0.2913 - accuracy: 0.8451 - val_loss: 1.8430 - val_accuracy: 0.6125
# Epoch 77/100
# 20/20 [==============================] - 7s 376ms/step - loss: 0.2990 - accuracy: 0.8451 - val_loss: 1.3993 - val_accuracy: 0.5625
# Epoch 78/100
# 20/20 [==============================] - 6s 303ms/step - loss: 0.2901 - accuracy: 0.8513 - val_loss: 1.8058 - val_accuracy: 0.6250
# Epoch 79/100
# 20/20 [==============================] - 7s 337ms/step - loss: 0.2801 - accuracy: 0.8451 - val_loss: 2.0497 - val_accuracy: 0.6125
# Epoch 80/100
# 20/20 [==============================] - 6s 323ms/step - loss: 0.2849 - accuracy: 0.8560 - val_loss: 1.6499 - val_accuracy: 0.6000
# Epoch 81/100
# 20/20 [==============================] - 6s 318ms/step - loss: 0.3136 - accuracy: 0.8419 - val_loss: 1.6454 - val_accuracy: 0.5125
# Epoch 82/100
# 20/20 [==============================] - 7s 379ms/step - loss: 0.3253 - accuracy: 0.8357 - val_loss: 1.9013 - val_accuracy: 0.5750
# Epoch 83/100
# 20/20 [==============================] - 6s 302ms/step - loss: 0.3163 - accuracy: 0.8451 - val_loss: 1.6518 - val_accuracy: 0.5875
# Epoch 84/100
# 20/20 [==============================] - 7s 378ms/step - loss: 0.3456 - accuracy: 0.8435 - val_loss: 1.8166 - val_accuracy: 0.5500
# Epoch 85/100
# 20/20 [==============================] - 6s 301ms/step - loss: 0.3145 - accuracy: 0.8326 - val_loss: 1.5606 - val_accuracy: 0.6000
# Epoch 86/100
# 20/20 [==============================] - 7s 371ms/step - loss: 0.3012 - accuracy: 0.8638 - val_loss: 1.9915 - val_accuracy: 0.6375
# Epoch 87/100
# 20/20 [==============================] - 6s 303ms/step - loss: 0.3394 - accuracy: 0.8419 - val_loss: 1.5919 - val_accuracy: 0.5875
# Epoch 88/100
# 20/20 [==============================] - 7s 353ms/step - loss: 0.2959 - accuracy: 0.8560 - val_loss: 1.9407 - val_accuracy: 0.6500
# Epoch 89/100
# 20/20 [==============================] - 6s 297ms/step - loss: 0.3184 - accuracy: 0.8372 - val_loss: 1.6674 - val_accuracy: 0.5750
# Epoch 90/100
# 20/20 [==============================] - 7s 374ms/step - loss: 0.2975 - accuracy: 0.8592 - val_loss: 1.7302 - val_accuracy: 0.5750
# Epoch 91/100
# 20/20 [==============================] - 6s 302ms/step - loss: 0.2953 - accuracy: 0.8529 - val_loss: 2.0622 - val_accuracy: 0.5750
# Epoch 92/100
# 20/20 [==============================] - 7s 376ms/step - loss: 0.2871 - accuracy: 0.8498 - val_loss: 1.9331 - val_accuracy: 0.6125
# Epoch 93/100
# 20/20 [==============================] - 6s 303ms/step - loss: 0.2805 - accuracy: 0.8482 - val_loss: 1.9798 - val_accuracy: 0.6250
# Epoch 94/100
# 20/20 [==============================] - 7s 343ms/step - loss: 0.3050 - accuracy: 0.8451 - val_loss: 1.9172 - val_accuracy: 0.5875
# Epoch 95/100
# 20/20 [==============================] - 6s 302ms/step - loss: 0.2969 - accuracy: 0.8388 - val_loss: 2.0741 - val_accuracy: 0.6500
# Epoch 96/100
# 20/20 [==============================] - 7s 376ms/step - loss: 0.2989 - accuracy: 0.8404 - val_loss: 1.7786 - val_accuracy: 0.5500
# Epoch 97/100
# 20/20 [==============================] - 6s 316ms/step - loss: 0.2799 - accuracy: 0.8592 - val_loss: 2.4636 - val_accuracy: 0.6125
# Epoch 98/100
# 20/20 [==============================] - 7s 370ms/step - loss: 0.3112 - accuracy: 0.8310 - val_loss: 1.8888 - val_accuracy: 0.5625
# Epoch 99/100
# 20/20 [==============================] - 6s 304ms/step - loss: 0.3006 - accuracy: 0.8466 - val_loss: 2.2096 - val_accuracy: 0.6125
# Epoch 100/100
# 20/20 [==============================] - 7s 372ms/step - loss: 0.2828 - accuracy: 0.8560 - val_loss: 2.0276 - val_accuracy: 0.5500

# %% [markdown]
# ### define function to print text in RGB foreground and background colors

# %%
def print_in_color(txt_msg,fore_tupple,back_tupple,):
    #prints the text_msg in the foreground color specified by fore_tupple with the background specified by back_tupple
    #text_msg is the text, fore_tupple is foregroud color tupple (r,g,b), back_tupple is background tupple (r,g,b)
    rf,gf,bf=fore_tupple
    rb,gb,bb=back_tupple
    msg='{0}' + txt_msg
    mat='\33[38;2;' + str(rf) +';' + str(gf) + ';' + str(bf) + ';48;2;' + str(rb) + ';' +str(gb) + ';' + str(bb) +'m'
    print(msg .format(mat), flush=True)
    print('\33[0m', flush=True) # returns default print color to back to black
    return

# %% [markdown]
# ### define function to plot the training data

# %%
def tr_plot(tr_data, start_epoch):
    #Plot the training and validation data
    tacc=tr_data.history['accuracy']
    tloss=tr_data.history['loss']
    vacc=tr_data.history['val_accuracy']
    vloss=tr_data.history['val_loss']
    Epoch_count=len(tacc)+ start_epoch
    Epochs=[]
    for i in range (start_epoch ,Epoch_count):
        Epochs.append(i+1)
    index_loss=np.argmin(vloss)#  this is the epoch with the lowest validation loss
    val_lowest=vloss[index_loss]
    index_acc=np.argmax(vacc)
    acc_highest=vacc[index_acc]
    plt.style.use('fivethirtyeight')
    sc_label='best epoch= '+ str(index_loss+1 +start_epoch)
    vc_label='best epoch= '+ str(index_acc + 1+ start_epoch)
    fig,axes=plt.subplots(nrows=1, ncols=2, figsize=(20,8))
    axes[0].plot(Epochs,tloss, 'r', label='Training loss')
    axes[0].plot(Epochs,vloss,'g',label='Validation loss' )
    axes[0].scatter(index_loss+1 +start_epoch,val_lowest, s=150, c= 'blue', label=sc_label)
    axes[0].set_title('Training and Validation Loss')
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[1].plot (Epochs,tacc,'r',label= 'Training Accuracy')
    axes[1].plot (Epochs,vacc,'g',label= 'Validation Accuracy')
    axes[1].scatter(index_acc+1 +start_epoch,acc_highest, s=150, c= 'blue', label=vc_label)
    axes[1].set_title('Training and Validation Accuracy')
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Accuracy')
    axes[1].legend()
    plt.tight_layout
    #plt.style.use('fivethirtyeight')
    plt.show()

# %% [markdown]
# ### define function to generate the confusion matrix and classification report

# %%
def print_info( test_gen, preds, print_code, save_dir, subject ):
    class_dict=test_gen.class_indices
    labels= test_gen.labels
    file_names= test_gen.filenames
    error_list=[]
    true_class=[]
    pred_class=[]
    prob_list=[]
    new_dict={}
    error_indices=[]
    y_pred=[]
    for key,value in class_dict.items():
        new_dict[value]=key             # dictionary {integer of class number: string of class name}
    # store new_dict as a text fine in the save_dir
    classes=list(new_dict.values())     # list of string of class names
    dict_as_text=str(new_dict)
    dict_name= subject + '-' +str(len(classes)) +'.txt'
    dict_path=os.path.join(save_dir,dict_name)
    with open(dict_path, 'w') as x_file:
        x_file.write(dict_as_text)
    errors=0
    for i, p in enumerate(preds):
        pred_index=np.argmax(p)
        true_index=labels[i]  # labels are integer values
        if pred_index != true_index: # a misclassification has occurred
            error_list.append(file_names[i])
            true_class.append(new_dict[true_index])
            pred_class.append(new_dict[pred_index])
            prob_list.append(p[pred_index])
            error_indices.append(true_index)
            errors=errors + 1
        y_pred.append(pred_index)
    if print_code !=0:
        if errors>0:
            if print_code>errors:
                r=errors
            else:
                r=print_code
            msg='{0:^28s}{1:^28s}{2:^28s}{3:^16s}'.format('Filename', 'Predicted Class' , 'True Class', 'Probability')
            print_in_color(msg, (0,255,0),(55,65,80))
            for i in range(r):
                split1=os.path.split(error_list[i])
                split2=os.path.split(split1[0])
                fname=split2[1] + '/' + split1[1]
                msg='{0:^28s}{1:^28s}{2:^28s}{3:4s}{4:^6.4f}'.format(fname, pred_class[i],true_class[i], ' ', prob_list[i])
                print_in_color(msg, (255,255,255), (55,65,60))
                #print(error_list[i]  , pred_class[i], true_class[i], prob_list[i])
        else:
            msg='With accuracy of 100 % there are no errors to print'
            print_in_color(msg, (0,255,0),(55,65,80))
    if errors>0:
        plot_bar=[]
        plot_class=[]
        for  key, value in new_dict.items():
            count=error_indices.count(key)
            if count!=0:
                plot_bar.append(count) # list containg how many times a class c had an error
                plot_class.append(value)   # stores the class
        fig=plt.figure()
        fig.set_figheight(len(plot_class)/3)
        fig.set_figwidth(10)
        plt.style.use('fivethirtyeight')
        for i in range(0, len(plot_class)):
            c=plot_class[i]
            x=plot_bar[i]
            plt.barh(c, x, )
            plt.title( ' Errors by Class on Test Set')
    y_true= np.array(labels)
    y_pred=np.array(y_pred)
    if len(classes)<= 30:
        # create a confusion matrix
        cm = confusion_matrix(y_true, y_pred )
        length=len(classes)
        if length<8:
            fig_width=8
            fig_height=8
        else:
            fig_width= int(length * .5)
            fig_height= int(length * .5)
        plt.figure(figsize=(fig_width, fig_height))
        sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)
        plt.xticks(np.arange(length)+.5, classes, rotation= 90)
        plt.yticks(np.arange(length)+.5, classes, rotation=0)
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix")
        plt.show()
    clr = classification_report(y_true, y_pred, target_names=classes)
    print("Classification Report:\n----------------------\n", clr)

# %% [markdown]
# ### evaluate model on the test set then save the model

# %%
tr_plot(history,0)
save_dir=r'./'
subject='road'
acc=model.evaluate( test_gen, batch_size=test_batch_size, verbose=1, steps=test_steps, return_dict=False)[1]*100
msg=f'accuracy on the test set is {acc:5.2f} %'
print_in_color(msg, (0,255,0),(55,65,80))
save_id=str (model_name +  '-' + subject +'-'+ str(acc)[:str(acc).rfind('.')+3] + '.h5')
save_loc=os.path.join(save_dir, save_id)
model.save(save_loc)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 1.6648 - accuracy: 0.6375
# accuracy on the test set is 63.75 %
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ### make predictions on test set and generate confusion matrix and classification report

# %%
print_code=0
preds=model.predict(test_gen)
print_info( test_gen, preds, print_code, save_dir, subject )
# Out:
# 1/1 [==============================] - 2s 2s/step
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#  jalan_retak       0.59      0.68      0.63        19
#  rusak_kecil       0.56      0.42      0.48        12
#  rusak_parah       0.83      0.62      0.71        24
# rusak_sedang       0.58      0.72      0.64        25
#
#     accuracy                           0.64        80
#    macro avg       0.64      0.61      0.62        80
# weighted avg       0.66      0.64      0.64        80
